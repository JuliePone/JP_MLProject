# %% [markdown]
# This exercise will require you to pull some data from the Qunadl API. Qaundl is currently the most widely used aggregator of financial market data.

# %% [markdown]
# As a first step, you will need to register a free account on the http://www.quandl.com website.

# %% [markdown]
# After you register, you will be provided with a unique API key, that you should store:

# %%
# Store the API key as a string - according to PEP8, constants are always named in all upper case
API_KEY = 'CeMyr24MyVqheK9FF32c'

# %% [markdown]
# Qaundl has a large number of data sources, but, unfortunately, most of them require a Premium subscription. Still, there are also a good number of free datasets.

# %% [markdown]
# For this mini project, we will focus on equities data from the Frankfurt Stock Exhange (FSE), which is available for free. We'll try and analyze the stock prices of a company called Carl Zeiss Meditec, which manufactures tools for eye examinations, as well as medical lasers for laser eye surgery: https://www.zeiss.com/meditec/int/home.html. The company is listed under the stock ticker AFX_X.

# %% [markdown]
# You can find the detailed Quandl API instructions here: https://docs.quandl.com/docs/time-series

# %% [markdown]
# While there is a dedicated Python package for connecting to the Quandl API, we would prefer that you use the *requests* package, which can be easily downloaded using *pip* or *conda*. You can find the documentation for the package here: http://docs.python-requests.org/en/master/

# %% [markdown]
# Finally, apart from the *requests* package, you are encouraged to not use any third party Python packages, such as *pandas*, and instead focus on what's available in the Python Standard Library (the *collections* module might come in handy: https://pymotw.com/3/collections/).
# Also, since you won't have access to DataFrames, you are encouraged to us Python's native data structures - preferably dictionaries, though some questions can also be answered using lists.
# You can read more on these data structures here: https://docs.python.org/3/tutorial/datastructures.html

# %% [markdown]
# Keep in mind that the JSON responses you will be getting from the API map almost one-to-one to Python's dictionaries. Unfortunately, they can be very nested, so make sure you read up on indexing dictionaries in the documentation provided above.

# %%
# First, import the relevant modules

import requests

# %%
# Now, call the Quandl API and pull out a small sample of the data (only one day) to get a glimpse
# into the JSON structure that will be returned
url = 'https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?start_date=2017-12-03&api_key=CeMyr24MyVqheK9FF32c'
r = requests.get(url, auth=('user', 'pass'))

# %%
# Inspect the JSON structure of the object you created, and take note of how nested it is,
# as well as the overall structure
r.json()
# Out:
# {'dataset': {'id': 10095370,
#   'dataset_code': 'AFX_X',
#   'database_code': 'FSE',
#   'name': 'Carl Zeiss Meditec (AFX_X)',
#   'description': 'Stock Prices for Carl Zeiss Meditec (2020-11-02) from the Frankfurt Stock Exchange.<br><br>Trading System: Xetra<br><br>ISIN: DE0005313704',
#   'refreshed_at': '2020-12-01T14:48:09.907Z',
#   'newest_available_date': '2020-12-01',
#   'oldest_available_date': '2000-06-07',
#   'column_names': ['Date',
#    'Open',
#    'High',
#    'Low',
#    'Close',
#    'Change',
#    'Traded Volume',
#    'Turnover',
#    'Last Price of the Day',
#    'Daily Traded Units',
#    'Daily Turnover'],
#   'frequency': 'daily',
#   'type': 'Time Series',
#   'premium': False,
#   'limit': None,
#   'transform': None,
#   'column_index': None,
#   'start_date': '2017-12-03',
#   'end_date': '2020-12-01',
#   'data': [['2020-12-01',
#     112.2,
#     112.2,
#     111.5,
#     112.0,
#     None,
#     51.0,
#     5703.0,
#     None,
#     None,
#     None],
#    ['2020-11-30',
#     111.0,
#     113.6,
#     111.0,
#     112.1,
#     None,
#     315.0,
#     35111.5,
#     None,
#     None,
#     None],
#    ['2020-11-27',
#     111.0,
#     111.5,
#     109.5,
#     111.2,
#     None,
#     155.0,
#     17168.5,
#     None,
#     None,
#     None],
#    ['2020-11-26',
#     111.3,
#     112.0,
#     110.5,
#     111.6,
#     None,
#     254.0,
#     28367.5,
#     None,
#     None,
#     None],
#    ['2020-11-25',
#     111.4,
#     111.4,
#     110.1,
#     110.1,
#     None,
#     294.0,
#     32435.8,
#     None,
#     None,
#     None],
#    ['2020-11-24',
#     116.1,
#     116.8,
#     110.5,
#     113.5,
#     None,
#     3184.0,
#     361404.4,
#     None,
#     None,
#     None],
#    ['2020-11-23',
#     118.0,
#     118.8,
#     116.3,
#     116.3,
#     None,
#     1590.0,
#     187525.0,
#     None,
#     None,
#     None],
#    ['2020-11-20',
#     116.5,
#     118.0,
#     116.5,
#     117.5,
#     None,
#     295.0,
#     34736.0,
#     None,
#     None,
#     None],
#    ['2020-11-19',
#     115.6,
#     115.6,
#     115.6,
#     115.6,
#     None,
#     0.0,
#     0.0,
#     None,
#     None,
#     None],
#    ['2020-11-18',
#     115.8,
#     115.8,
#     115.0,
#     115.0,
#     None,
#     25.0,
#     2875.0,
#     None,
#     None,
#     None],
#    ['2020-11-17',
#     117.9,
#     117.9,
#     115.7,
#     115.7,
#     None,
#     381.0,
#     44235.6,
#     None,
#     None,
#     None],
#    ['2020-11-16',
#     118.9,
#     119.8,
#     118.1,
#     118.1,
#     None,
#     266.0,
#     31637.8,
#     None,
#     None,
#     None],
#    ['2020-11-13',
#     115.4,
#     117.2,
#     115.4,
#     117.2,
#     None,
#     162.0,
#     18892.3,
#     None,
#     None,
#     None],
#    ['2020-11-12',
#     117.1,
#     117.5,
#     116.4,
#     116.4,
#     None,
#     185.0,
#     21587.5,
#     None,
#     None,
#     None],
#    ['2020-11-11',
#     115.0,
#     117.3,
#     115.0,
#     116.9,
#     None,
#     353.0,
#     41227.0,
#     None,
#     None,
#     None],
#    ['2020-11-10',
#     118.4,
#     118.4,
#     114.6,
#     114.6,
#     None,
#     93.0,
#     10801.6,
#     None,
#     None,
#     None],
#    ['2020-11-09',
#     116.1,
#     119.9,
#     116.1,
#     119.4,
#     None,
#     494.0,
#     58880.6,
#     None,
#     None,
#     None],
#    ['2020-11-06',
#     115.2,
#     115.8,
#     114.8,
#     115.1,
#     None,
#     190.0,
#     21831.0,
#     None,
#     None,
#     None],
#    ['2020-11-05',
#     114.7,
#     116.2,
#     114.7,
#     115.4,
#     None,
#     382.0,
#     44272.4,
#     None,
#     None,
#     None],
#    ['2020-11-04',
#     109.8,
#     113.8,
#     109.8,
#     113.8,
#     None,
#     69.0,
#     7804.7,
#     None,
#     None,
#     None],
#    ['2020-11-03',
#     108.4,
#     110.0,
#     108.4,
#     110.0,
#     None,
#     176.0,
#     19259.0,
#     None,
#     None,
#     None],
#    ['2020-11-02',
#     111.3,
#     111.6,
#     108.1,
#     108.1,
#     None,
#     362.0,
#     39844.5,
#     None,
#     None,
#     None],
#    ['2020-10-30',
#     107.2,
#     112.9,
#     107.2,
#     110.7,
#     None,
#     99.0,
#     11001.5,
#     None,
#     None,
#     None],
#    ['2020-10-29',
#     112.1,
#     113.0,
#     106.7,
#     109.5,
#     None,
#     395.0,
#     43369.2,
#     None,
#     None,
#     None],
#    ['2020-10-28',
#     113.7,
#     113.7,
#     106.1,
#     111.8,
#     None,
#     861.0,
#     94248.9,
#     None,
#     None,
#     None],
#    ['2020-10-27',
#     115.6,
#     115.8,
#     114.9,
#     114.9,
#     None,
#     360.0,
#     41598.0,
#     None,
#     None,
#     None],
#    ['2020-10-26',
#     117.5,
#     117.5,
#     113.4,
#     113.7,
#     None,
#     694.0,
#     80177.1,
#     None,
#     None,
#     None],
#    ['2020-10-23',
#     120.4,
#     121.1,
#     115.0,
#     118.5,
#     None,
#     813.0,
#     96193.0,
#     None,
#     None,
#     None],
#    ['2020-10-22',
#     119.5,
#     121.9,
#     118.8,
#     121.5,
#     None,
#     260.0,
#     31396.4,
#     None,
#     None,
#     None],
#    ['2020-10-21',
#     121.8,
#     121.9,
#     119.9,
#     120.6,
#     None,
#     2148.0,
#     258027.5,
#     None,
#     None,
#     None],
#    ['2020-10-20',
#     122.1,
#     123.2,
#     121.8,
#     123.2,
#     None,
#     55.0,
#     6706.0,
#     None,
#     None,
#     None],
#    ['2020-10-19',
#     121.6,
#     123.7,
#     121.6,
#     122.8,
#     None,
#     264.0,
#     32417.3,
#     None,
#     None,
#     None],
#    ['2020-10-16',
#     118.6,
#     122.4,
#     118.6,
#     121.4,
#     None,
#     320.0,
#     39037.3,
#     None,
#     None,
#     None],
#    ['2020-10-15',
#     121.0,
#     121.2,
#     118.5,
#     118.7,
#     None,
#     853.0,
#     102179.6,
#     None,
#     None,
#     None],
#    ['2020-10-14',
#     118.6,
#     122.1,
#     118.6,
#     122.1,
#     None,
#     507.0,
#     61486.3,
#     None,
#     None,
#     None],
#    ['2020-10-13',
#     120.3,
#     120.9,
#     117.8,
#     118.7,
#     None,
#     351.0,
#     41428.7,
#     None,
#     None,
#     None],
#    ['2020-10-12',
#     115.8,
#     120.6,
#     115.8,
#     120.5,
#     None,
#     331.0,
#     39564.3,
#     None,
#     None,
#     None],
#    ['2020-10-09',
#     114.0,
#     116.2,
#     113.9,
#     116.2,
#     None,
#     1298.0,
#     149551.9,
#     None,
#     None,
#     None],
#    ['2020-10-08',
#     112.1,
#     114.5,
#     112.1,
#     114.5,
#     None,
#     392.0,
#     44587.1,
#     None,
#     None,
#     None],
#    ['2020-10-07',
#     112.0,
#     112.7,
#     111.3,
#     112.7,
#     None,
#     202.0,
#     22687.6,
#     None,
#     None,
#     None],
#    ['2020-10-06',
#     110.4,
#     111.8,
#     110.4,
#     111.8,
#     None,
#     450.0,
#     50030.0,
#     None,
#     None,
#     None],
#    ['2020-10-05',
#     109.3,
#     110.9,
#     109.3,
#     110.9,
#     None,
#     64.0,
#     7068.6,
#     None,
#     None,
#     None],
#    ['2020-10-02',
#     108.0,
#     109.6,
#     108.0,
#     109.6,
#     None,
#     177.0,
#     19153.5,
#     None,
#     None,
#     None],
#    ['2020-10-01',
#     108.1,
#     109.5,
#     108.1,
#     109.5,
#     None,
#     70.0,
#     7650.0,
#     None,
#     None,
#     None],
#    ['2020-09-30',
#     108.6,
#     108.6,
#     106.8,
#     106.8,
#     None,
#     271.0,
#     29094.6,
#     None,
#     None,
#     None],
#    ['2020-09-29',
#     106.9,
#     109.4,
#     106.9,
#     109.4,
#     None,
#     76.0,
#     8253.9,
#     None,
#     None,
#     None],
#    ['2020-09-28',
#     105.0,
#     107.3,
#     105.0,
#     107.1,
#     None,
#     472.0,
#     50326.6,
#     None,
#     None,
#     None],
#    ['2020-09-25',
#     103.2,
#     104.4,
#     103.0,
#     103.7,
#     None,
#     763.0,
#     78994.1,
#     None,
#     None,
#     None],
#    ['2020-09-24',
#     100.5,
#     103.8,
#     100.5,
#     103.8,
#     None,
#     152.0,
#     15708.0,
#     None,
#     None,
#     None],
#    ['2020-09-23',
#     101.0,
#     101.7,
#     100.6,
#     101.7,
#     None,
#     368.0,
#     37374.3,
#     None,
#     None,
#     None],
#    ['2020-09-22',
#     98.5,
#     100.0,
#     98.5,
#     100.0,
#     None,
#     190.0,
#     18865.0,
#     None,
#     None,
#     None],
#    ['2020-09-21',
#     101.7,
#     101.7,
#     98.2,
#     98.2,
#     None,
#     300.0,
#     30299.0,
#     None,
#     None,
#     None],
#    ['2020-09-18',
#     100.1,
#     101.2,
#     100.1,
#     101.2,
#     None,
#     209.0,
#     21100.8,
#     None,
#     None,
#     None],
#    ['2020-09-17',
#     96.1,
#     102.0,
#     96.0,
#     102.0,
#     None,
#     433.0,
#     42836.5,
#     None,
#     None,
#     None],
#    ['2020-09-16',
#     93.1,
#     95.95,
#     93.1,
#     95.95,
#     None,
#     45.0,
#     4241.25,
#     None,
#     None,
#     None],
#    ['2020-09-15',
#     92.5,
#     92.5,
#     92.15,
#     92.4,
#     None,
#     167.0,
#     15414.45,
#     None,
#     None,
#     None],
#    ['2020-09-14',
#     93.1,
#     93.1,
#     93.0,
#     93.0,
#     None,
#     25.0,
#     2326.0,
#     None,
#     None,
#     None],
#    ['2020-09-11',
#     93.85,
#     93.85,
#     92.5,
#     92.5,
#     None,
#     70.0,
#     6475.0,
#     None,
#     None,
#     None],
#    ['2020-09-10',
#     95.6,
#     95.6,
#     94.55,
#     94.55,
#     None,
#     110.0,
#     10495.5,
#     None,
#     None,
#     None],
#    ['2020-09-09',
#     94.75,
#     95.85,
#     94.4,
#     95.85,
#     None,
#     411.0,
#     38950.25,
#     None,
#     None,
#     None],
#    ['2020-09-08',
#     96.3,
#     96.3,
#     93.3,
#     94.75,
#     None,
#     165.0,
#     15516.5,
#     None,
#     None,
#     None],
#    ['2020-09-07',
#     93.5,
#     95.95,
#     93.5,
#     95.95,
#     None,
#     160.0,
#     15074.5,
#     None,
#     None,
#     None],
#    ['2020-09-04',
#     94.5,
#     94.5,
#     93.15,
#     93.15,
#     None,
#     350.0,
#     32790.25,
#     None,
#     None,
#     None],
#    ['2020-09-03',
#     99.1,
#     99.1,
#     94.8,
#     95.0,
#     None,
#     382.0,
#     36699.7,
#     None,
#     None,
#     None],
#    ['2020-09-02',
#     94.75,
#     99.05,
#     94.75,
#     98.75,
#     None,
#     582.0,
#     56936.55,
#     None,
#     None,
#     None],
#    ['2020-09-01',
#     94.6,
#     95.0,
#     94.55,
#     94.55,
#     None,
#     385.0,
#     36427.5,
#     None,
#     None,
#     None],
#    ['2020-08-31',
#     94.75,
#     94.75,
#     94.35,
#     94.35,
#     None,
#     175.0,
#     16541.25,
#     None,
#     None,
#     None],
#    ['2020-08-28',
#     95.0,
#     95.5,
#     93.8,
#     95.3,
#     None,
#     98882.0,
#     9370950.35,
#     None,
#     None,
#     None],
#    ['2020-08-27',
#     95.7,
#     96.0,
#     94.5,
#     94.8,
#     None,
#     142753.0,
#     13576918.75,
#     None,
#     None,
#     None],
#    ['2020-08-26',
#     94.25,
#     95.5,
#     94.05,
#     95.4,
#     None,
#     82485.0,
#     7827754.45,
#     None,
#     None,
#     None],
#    ['2020-08-25',
#     93.85,
#     94.75,
#     93.45,
#     94.5,
#     None,
#     89082.0,
#     8397454.8,
#     None,
#     None,
#     None],
#    ['2020-08-24',
#     92.3,
#     94.5,
#     92.3,
#     93.5,
#     None,
#     119117.0,
#     11168837.75,
#     None,
#     None,
#     None],
#    ['2020-08-21',
#     92.15,
#     92.2,
#     90.65,
#     91.9,
#     None,
#     65210.0,
#     5976477.15,
#     None,
#     None,
#     None],
#    ['2020-08-20',
#     91.0,
#     92.4,
#     90.45,
#     92.15,
#     None,
#     95493.0,
#     8763119.9,
#     None,
#     None,
#     None],
#    ['2020-08-19',
#     91.0,
#     92.2,
#     90.0,
#     91.65,
#     None,
#     88102.0,
#     8063097.4,
#     None,
#     None,
#     None],
#    ['2020-08-18',
#     91.55,
#     92.0,
#     90.4,
#     91.0,
#     None,
#     85470.0,
#     7789882.4,
#     None,
#     None,
#     None],
#    ['2020-08-17',
#     91.6,
#     91.95,
#     90.55,
#     91.9,
#     None,
#     58566.0,
#     5357104.3,
#     None,
#     None,
#     None],
#    ['2020-08-14',
#     92.9,
#     93.25,
#     91.35,
#     91.85,
#     None,
#     78700.0,
#     7257628.1,
#     None,
#     None,
#     None],
#    ['2020-08-13',
#     92.2,
#     93.0,
#     91.1,
#     92.85,
#     None,
#     98209.0,
#     9080452.6,
#     None,
#     None,
#     None],
#    ['2020-08-12',
#     90.8,
#     92.95,
#     88.3,
#     92.65,
#     None,
#     182444.0,
#     16598657.95,
#     None,
#     None,
#     None],
#    ['2020-08-11',
#     94.9,
#     95.4,
#     90.35,
#     90.75,
#     None,
#     168948.0,
#     15524389.1,
#     None,
#     None,
#     None],
#    ['2020-08-10',
#     94.0,
#     96.0,
#     93.75,
#     94.55,
#     None,
#     183320.0,
#     17388579.4,
#     None,
#     None,
#     None],
#    ['2020-08-07',
#     90.2,
#     93.15,
#     89.8,
#     92.95,
#     None,
#     109450.0,
#     10126152.1,
#     None,
#     None,
#     None],
#    ['2020-08-06',
#     91.45,
#     92.0,
#     90.35,
#     91.1,
#     None,
#     140089.0,
#     12778666.3,
#     None,
#     None,
#     None],
#    ['2020-08-05',
#     89.85,
#     91.85,
#     88.75,
#     91.85,
#     None,
#     147638.0,
#     13413298.3,
#     None,
#     None,
#     None],
#    ['2020-08-04',
#     90.5,
#     91.1,
#     88.25,
#     89.05,
#     None,
#     110318.0,
#     9813561.0,
#     None,
#     None,
#     None],
#    ['2020-08-03',
#     89.0,
#     90.5,
#     88.2,
#     90.0,
#     None,
#     95661.0,
#     8591521.9,
#     None,
#     None,
#     None],
#    ['2020-07-31',
#     89.4,
#     90.95,
#     88.5,
#     88.65,
#     None,
#     145927.0,
#     13058046.1,
#     None,
#     None,
#     None],
#    ['2020-07-30',
#     91.7,
#     91.75,
#     88.1,
#     89.6,
#     None,
#     182764.0,
#     16464224.8,
#     None,
#     None,
#     None],
#    ['2020-07-29',
#     88.55,
#     92.25,
#     88.2,
#     92.25,
#     None,
#     169549.0,
#     15522318.75,
#     None,
#     None,
#     None],
#    ['2020-07-28',
#     89.5,
#     89.75,
#     88.35,
#     88.85,
#     None,
#     116461.0,
#     10345922.4,
#     None,
#     None,
#     None],
#    ['2020-07-27',
#     88.0,
#     89.55,
#     87.35,
#     89.15,
#     None,
#     102146.0,
#     9082131.05,
#     None,
#     None,
#     None],
#    ['2020-07-24',
#     90.5,
#     90.5,
#     87.85,
#     87.9,
#     None,
#     177031.0,
#     15683394.95,
#     None,
#     None,
#     None],
#    ['2020-07-23',
#     88.4,
#     91.55,
#     88.15,
#     91.55,
#     None,
#     146866.0,
#     13280553.85,
#     None,
#     None,
#     None],
#    ['2020-07-22',
#     88.6,
#     89.1,
#     87.4,
#     88.75,
#     None,
#     101234.0,
#     8954258.2,
#     None,
#     None,
#     None],
#    ['2020-07-21',
#     89.55,
#     89.95,
#     87.75,
#     88.5,
#     None,
#     195028.0,
#     17331900.8,
#     None,
#     None,
#     None],
#    ['2020-07-20',
#     88.25,
#     89.5,
#     87.55,
#     88.95,
#     None,
#     227635.0,
#     20134893.65,
#     None,
#     None,
#     None],
#    ['2020-07-17',
#     89.15,
#     90.5,
#     88.0,
#     88.4,
#     None,
#     163078.0,
#     14464839.25,
#     None,
#     None,
#     None],
#    ['2020-07-16',
#     90.65,
#     90.65,
#     87.9,
#     88.95,
#     None,
#     197755.0,
#     17652520.05,
#     None,
#     None,
#     None],
#    ['2020-07-15',
#     90.0,
#     91.7,
#     86.3,
#     91.7,
#     None,
#     258220.0,
#     23077220.7,
#     None,
#     None,
#     None],
#    ['2020-07-14',
#     90.1,
#     90.15,
#     88.1,
#     89.2,
#     None,
#     183507.0,
#     16350975.75,
#     None,
#     None,
#     None],
#    ['2020-07-13',
#     90.45,
#     91.15,
#     88.6,
#     91.05,
#     None,
#     87454.0,
#     7915927.0,
#     None,
#     None,
#     None],
#    ['2020-07-10',
#     89.25,
#     91.55,
#     88.9,
#     89.9,
#     None,
#     93540.0,
#     8453243.25,
#     None,
#     None,
#     None],
#    ['2020-07-09',
#     91.15,
#     91.35,
#     89.45,
#     89.55,
#     None,
#     181776.0,
#     16405326.65,
#     None,
#     None,
#     None],
#    ['2020-07-08',
#     92.0,
#     92.55,
#     90.15,
#     90.3,
#     None,
#     153582.0,
#     13970079.05,
#     None,
#     None,
#     None],
#    ['2020-07-07',
#     92.95,
#     93.65,
#     91.15,
#     92.5,
#     None,
#     153153.0,
#     14109118.8,
#     None,
#     None,
#     None],
#    ['2020-07-06',
#     93.8,
#     93.9,
#     92.8,
#     93.8,
#     None,
#     98508.0,
#     9199714.85,
#     None,
#     None,
#     None],
#    ['2020-07-03',
#     93.1,
#     93.85,
#     91.9,
#     92.35,
#     None,
#     114471.0,
#     10617857.55,
#     None,
#     None,
#     None],
#    ['2020-07-02',
#     89.75,
#     93.8,
#     88.8,
#     92.85,
#     None,
#     365676.0,
#     33662061.9,
#     None,
#     None,
#     None],
#    ['2020-07-01',
#     86.2,
#     89.25,
#     86.0,
#     89.25,
#     None,
#     106604.0,
#     9438618.8,
#     None,
#     None,
#     None],
#    ['2020-06-30',
#     87.0,
#     87.15,
#     85.0,
#     86.8,
#     None,
#     138372.0,
#     11944211.15,
#     None,
#     None,
#     None],
#    ['2020-06-29',
#     88.0,
#     88.85,
#     86.5,
#     87.05,
#     None,
#     76589.0,
#     6688133.9,
#     None,
#     None,
#     None],
#    ['2020-06-26',
#     88.2,
#     89.4,
#     86.65,
#     88.05,
#     None,
#     123809.0,
#     10922723.5,
#     None,
#     None,
#     None],
#    ['2020-06-25',
#     86.25,
#     88.25,
#     84.8,
#     87.8,
#     None,
#     118166.0,
#     10302946.05,
#     None,
#     None,
#     None],
#    ['2020-06-24',
#     90.05,
#     90.25,
#     86.2,
#     86.2,
#     None,
#     115847.0,
#     10143798.5,
#     None,
#     None,
#     None],
#    ['2020-06-23',
#     89.2,
#     91.0,
#     88.6,
#     89.95,
#     None,
#     112453.0,
#     10108636.8,
#     None,
#     None,
#     None],
#    ['2020-06-22',
#     90.35,
#     90.7,
#     87.85,
#     88.55,
#     None,
#     116991.0,
#     10394476.9,
#     None,
#     None,
#     None],
#    ['2020-06-19',
#     90.55,
#     91.8,
#     90.0,
#     91.25,
#     None,
#     174766.0,
#     15936379.65,
#     None,
#     None,
#     None],
#    ['2020-06-18',
#     91.6,
#     91.85,
#     89.6,
#     90.05,
#     None,
#     98019.0,
#     8859710.65,
#     None,
#     None,
#     None],
#    ['2020-06-17',
#     90.55,
#     92.15,
#     89.7,
#     91.45,
#     None,
#     149331.0,
#     13655800.2,
#     None,
#     None,
#     None],
#    ['2020-06-16',
#     88.35,
#     90.75,
#     87.45,
#     90.65,
#     None,
#     206243.0,
#     18478591.35,
#     None,
#     None,
#     None],
#    ['2020-06-15',
#     85.0,
#     86.9,
#     84.75,
#     86.35,
#     None,
#     181008.0,
#     15502164.95,
#     None,
#     None,
#     None],
#    ['2020-06-12',
#     85.65,
#     87.9,
#     84.85,
#     86.4,
#     None,
#     137604.0,
#     11931180.75,
#     None,
#     None,
#     None],
#    ['2020-06-11',
#     87.0,
#     87.65,
#     85.55,
#     86.3,
#     None,
#     127406.0,
#     11026683.1,
#     None,
#     None,
#     None],
#    ['2020-06-10',
#     89.25,
#     90.1,
#     87.0,
#     87.8,
#     None,
#     192426.0,
#     16965135.2,
#     None,
#     None,
#     None],
#    ['2020-06-09',
#     91.65,
#     93.25,
#     89.2,
#     89.35,
#     None,
#     209173.0,
#     18983014.7,
#     None,
#     None,
#     None],
#    ['2020-06-08',
#     92.65,
#     92.65,
#     89.8,
#     91.7,
#     None,
#     172403.0,
#     15698539.85,
#     None,
#     None,
#     None],
#    ['2020-06-05',
#     91.6,
#     93.3,
#     90.65,
#     93.15,
#     None,
#     185077.0,
#     17116028.75,
#     None,
#     None,
#     None],
#    ['2020-06-04',
#     92.3,
#     92.8,
#     89.65,
#     91.4,
#     None,
#     238456.0,
#     21679333.75,
#     None,
#     None,
#     None],
#    ['2020-06-03',
#     91.15,
#     93.3,
#     89.65,
#     92.9,
#     None,
#     144255.0,
#     13282471.95,
#     None,
#     None,
#     None],
#    ['2020-06-02',
#     93.3,
#     93.5,
#     89.5,
#     91.0,
#     None,
#     165446.0,
#     15036505.55,
#     None,
#     None,
#     None],
#    ['2020-05-29',
#     91.05,
#     93.1,
#     90.25,
#     92.1,
#     None,
#     238162.0,
#     21887648.1,
#     None,
#     None,
#     None],
#    ['2020-05-28',
#     88.1,
#     91.7,
#     87.4,
#     91.45,
#     None,
#     228651.0,
#     14809122.8,
#     None,
#     None,
#     None],
#    ['2020-05-27',
#     91.0,
#     91.2,
#     86.4,
#     87.3,
#     None,
#     292506.0,
#     25754496.6,
#     None,
#     None,
#     None],
#    ['2020-05-26',
#     91.1,
#     93.35,
#     89.7,
#     90.85,
#     None,
#     295589.0,
#     27089139.05,
#     None,
#     None,
#     None],
#    ['2020-05-25',
#     88.6,
#     92.7,
#     88.1,
#     92.6,
#     None,
#     101335.0,
#     9240143.65,
#     None,
#     None,
#     None],
#    ['2020-05-22',
#     87.35,
#     88.5,
#     85.45,
#     87.65,
#     None,
#     170878.0,
#     14839809.55,
#     None,
#     None,
#     None],
#    ['2020-05-21',
#     90.95,
#     90.95,
#     87.8,
#     87.9,
#     None,
#     103051.0,
#     9147975.45,
#     None,
#     None,
#     None],
#    ['2020-05-20',
#     92.5,
#     93.3,
#     91.3,
#     91.8,
#     None,
#     169820.0,
#     15657134.85,
#     None,
#     None,
#     None],
#    ['2020-05-19',
#     90.45,
#     92.8,
#     89.8,
#     92.5,
#     None,
#     215504.0,
#     19826326.1,
#     None,
#     None,
#     None],
#    ['2020-05-18',
#     85.45,
#     89.95,
#     84.9,
#     89.65,
#     None,
#     202085.0,
#     17790850.8,
#     None,
#     None,
#     None],
#    ['2020-05-15',
#     82.25,
#     84.85,
#     80.65,
#     83.8,
#     None,
#     219726.0,
#     18211281.9,
#     None,
#     None,
#     None],
#    ['2020-05-14',
#     84.7,
#     85.3,
#     81.15,
#     81.35,
#     None,
#     227178.0,
#     18722697.45,
#     None,
#     None,
#     None],
#    ['2020-05-13',
#     85.5,
#     87.9,
#     83.8,
#     85.75,
#     None,
#     229089.0,
#     19608050.05,
#     None,
#     None,
#     None],
#    ['2020-05-12',
#     91.55,
#     91.55,
#     86.0,
#     86.0,
#     None,
#     332344.0,
#     29093515.5,
#     None,
#     None,
#     None],
#    ['2020-05-11',
#     97.0,
#     97.7,
#     90.75,
#     91.8,
#     None,
#     202683.0,
#     18762257.75,
#     None,
#     None,
#     None],
#    ['2020-05-08',
#     96.35,
#     97.35,
#     95.15,
#     95.3,
#     None,
#     134071.0,
#     12869764.45,
#     None,
#     None,
#     None],
#    ['2020-05-07',
#     94.55,
#     97.25,
#     94.25,
#     96.0,
#     None,
#     210096.0,
#     20200879.55,
#     None,
#     None,
#     None],
#    ['2020-05-06',
#     92.8,
#     94.7,
#     91.45,
#     93.95,
#     None,
#     129479.0,
#     12095616.85,
#     None,
#     None,
#     None],
#    ['2020-05-05',
#     88.9,
#     92.6,
#     88.25,
#     92.6,
#     None,
#     131163.0,
#     12019019.15,
#     None,
#     None,
#     None],
#    ['2020-05-04',
#     87.65,
#     88.1,
#     85.95,
#     87.65,
#     None,
#     168947.0,
#     14745103.15,
#     None,
#     None,
#     None],
#    ['2020-04-30',
#     91.6,
#     92.1,
#     89.9,
#     89.95,
#     None,
#     137448.0,
#     12454130.55,
#     None,
#     None,
#     None],
#    ['2020-04-29',
#     90.0,
#     91.0,
#     87.85,
#     90.95,
#     None,
#     143888.0,
#     12901979.9,
#     None,
#     None,
#     None],
#    ['2020-04-28',
#     92.0,
#     92.2,
#     89.15,
#     89.65,
#     None,
#     163949.0,
#     14804941.85,
#     None,
#     None,
#     None],
#    ['2020-04-27',
#     95.05,
#     95.35,
#     92.1,
#     92.1,
#     None,
#     109266.0,
#     10128133.7,
#     None,
#     None,
#     None],
#    ['2020-04-24',
#     94.4,
#     94.6,
#     92.35,
#     93.1,
#     None,
#     111240.0,
#     10358166.75,
#     None,
#     None,
#     None],
#    ['2020-04-23',
#     94.75,
#     95.5,
#     92.7,
#     94.8,
#     None,
#     123862.0,
#     11684265.45,
#     None,
#     None,
#     None],
#    ['2020-04-22',
#     92.75,
#     94.65,
#     91.6,
#     94.65,
#     None,
#     126830.0,
#     11898048.5,
#     None,
#     None,
#     None],
#    ['2020-04-21',
#     93.4,
#     93.95,
#     91.5,
#     91.5,
#     None,
#     115152.0,
#     10603440.3,
#     None,
#     None,
#     None],
#    ['2020-04-20',
#     94.0,
#     94.65,
#     91.9,
#     94.15,
#     None,
#     124634.0,
#     11640880.35,
#     None,
#     None,
#     None],
#    ['2020-04-17',
#     93.4,
#     94.05,
#     91.85,
#     92.9,
#     None,
#     185554.0,
#     17165035.1,
#     None,
#     None,
#     None],
#    ['2020-04-16',
#     91.9,
#     92.75,
#     90.7,
#     91.45,
#     None,
#     162831.0,
#     14907520.55,
#     None,
#     None,
#     None],
#    ['2020-04-15',
#     94.0,
#     94.6,
#     90.15,
#     90.95,
#     None,
#     204001.0,
#     18647943.8,
#     None,
#     None,
#     None],
#    ['2020-04-14',
#     97.5,
#     98.0,
#     93.35,
#     94.05,
#     None,
#     147594.0,
#     13964369.1,
#     None,
#     None,
#     None],
#    ['2020-04-09',
#     93.1,
#     95.4,
#     92.05,
#     95.4,
#     None,
#     161578.0,
#     15199731.2,
#     None,
#     None,
#     None],
#    ['2020-04-08',
#     90.2,
#     92.25,
#     89.8,
#     92.2,
#     None,
#     152911.0,
#     14008042.75,
#     None,
#     None,
#     None],
#    ['2020-04-07',
#     92.0,
#     92.55,
#     88.9,
#     89.5,
#     None,
#     218796.0,
#     19809733.65,
#     None,
#     None,
#     None],
#    ['2020-04-06',
#     86.35,
#     89.65,
#     86.25,
#     89.65,
#     None,
#     165074.0,
#     14584495.75,
#     None,
#     None,
#     None],
#    ['2020-04-03',
#     83.1,
#     85.45,
#     82.5,
#     84.0,
#     None,
#     184124.0,
#     15495174.4,
#     None,
#     None,
#     None],
#    ['2020-04-02',
#     86.0,
#     87.15,
#     79.5,
#     82.5,
#     None,
#     300359.0,
#     24916457.15,
#     None,
#     None,
#     None],
#    ['2020-04-01',
#     86.5,
#     86.9,
#     85.0,
#     86.1,
#     None,
#     192187.0,
#     16541381.35,
#     None,
#     None,
#     None],
#    ['2020-03-31',
#     92.0,
#     92.65,
#     88.15,
#     88.35,
#     None,
#     311491.0,
#     27892906.55,
#     None,
#     None,
#     None],
#    ['2020-03-30',
#     85.4,
#     88.9,
#     83.1,
#     88.9,
#     None,
#     167955.0,
#     14624880.3,
#     None,
#     None,
#     None],
#    ['2020-03-27',
#     89.0,
#     90.85,
#     83.5,
#     83.95,
#     None,
#     231618.0,
#     19986099.3,
#     None,
#     None,
#     None],
#    ['2020-03-26',
#     81.5,
#     91.05,
#     81.5,
#     91.05,
#     None,
#     274322.0,
#     23971500.55,
#     None,
#     None,
#     None],
#    ['2020-03-25',
#     82.5,
#     90.4,
#     80.6,
#     83.1,
#     None,
#     284087.0,
#     23870691.15,
#     None,
#     None,
#     None],
#    ['2020-03-24',
#     79.2,
#     79.45,
#     76.6,
#     79.45,
#     None,
#     256310.0,
#     20107995.1,
#     None,
#     None,
#     None],
#    ['2020-03-23',
#     74.5,
#     77.05,
#     72.9,
#     75.0,
#     None,
#     187013.0,
#     14032458.1,
#     None,
#     None,
#     None],
#    ['2020-03-20',
#     76.65,
#     82.35,
#     75.7,
#     78.25,
#     None,
#     446534.0,
#     34997042.95,
#     None,
#     None,
#     None],
#    ['2020-03-19',
#     69.15,
#     74.7,
#     67.7,
#     73.45,
#     None,
#     272648.0,
#     19466640.1,
#     None,
#     None,
#     None],
#    ['2020-03-18',
#     74.5,
#     75.25,
#     69.55,
#     69.7,
#     None,
#     341817.0,
#     24444114.6,
#     None,
#     None,
#     None],
#    ['2020-03-17',
#     79.0,
#     80.1,
#     73.5,
#     75.1,
#     None,
#     265313.0,
#     20046246.2,
#     None,
#     None,
#     None],
#    ['2020-03-16',
#     75.0,
#     76.9,
#     71.45,
#     76.15,
#     None,
#     422533.0,
#     31664759.85,
#     None,
#     None,
#     None],
#    ['2020-03-13',
#     77.75,
#     84.05,
#     76.85,
#     78.85,
#     None,
#     457906.0,
#     36529317.4,
#     None,
#     None,
#     None],
#    ['2020-03-12',
#     77.75,
#     81.65,
#     75.8,
#     76.45,
#     None,
#     428846.0,
#     33545984.85,
#     None,
#     None,
#     None],
#    ['2020-03-11',
#     87.6,
#     88.45,
#     83.85,
#     84.3,
#     None,
#     250339.0,
#     21276696.5,
#     None,
#     None,
#     None],
#    ['2020-03-10',
#     88.25,
#     90.3,
#     86.0,
#     86.8,
#     None,
#     324702.0,
#     28663267.75,
#     None,
#     None,
#     None],
#    ['2020-03-09',
#     87.65,
#     92.15,
#     85.1,
#     87.2,
#     None,
#     392049.0,
#     34832184.95,
#     None,
#     None,
#     None],
#    ['2020-03-06',
#     95.0,
#     95.1,
#     91.9,
#     94.15,
#     None,
#     211996.0,
#     19868077.2,
#     None,
#     None,
#     None],
#    ['2020-03-05',
#     101.3,
#     102.6,
#     96.35,
#     97.2,
#     None,
#     230406.0,
#     22585334.7,
#     None,
#     None,
#     None],
#    ['2020-03-04',
#     98.3,
#     100.5,
#     97.55,
#     100.1,
#     None,
#     251085.0,
#     24993655.35,
#     None,
#     None,
#     None],
#    ['2020-03-03',
#     97.1,
#     99.9,
#     95.55,
#     98.05,
#     None,
#     435677.0,
#     42953287.0,
#     None,
#     None,
#     None],
#    ['2020-03-02',
#     96.5,
#     98.3,
#     93.55,
#     95.05,
#     None,
#     285867.0,
#     27318381.65,
#     None,
#     None,
#     None],
#    ['2020-02-28',
#     90.05,
#     94.75,
#     89.65,
#     94.75,
#     None,
#     468539.0,
#     43691138.55,
#     None,
#     None,
#     None],
#    ['2020-02-27',
#     97.95,
#     98.3,
#     93.75,
#     95.05,
#     None,
#     253380.0,
#     24293170.5,
#     None,
#     None,
#     None],
#    ['2020-02-26',
#     98.5,
#     100.8,
#     96.35,
#     100.2,
#     None,
#     371150.0,
#     36784605.3,
#     None,
#     None,
#     None],
#    ['2020-02-25',
#     105.6,
#     106.4,
#     100.6,
#     101.2,
#     None,
#     250020.0,
#     25613306.6,
#     None,
#     None,
#     None],
#    ['2020-02-24',
#     104.0,
#     105.5,
#     102.2,
#     104.7,
#     None,
#     211543.0,
#     22050204.4,
#     None,
#     None,
#     None],
#    ['2020-02-21',
#     110.1,
#     110.2,
#     107.7,
#     108.2,
#     None,
#     119055.0,
#     12948891.0,
#     None,
#     None,
#     None],
#    ['2020-02-20',
#     111.3,
#     112.8,
#     109.9,
#     110.4,
#     None,
#     139229.0,
#     15421757.0,
#     None,
#     None,
#     None],
#    ['2020-02-19',
#     110.3,
#     112.4,
#     109.5,
#     111.2,
#     None,
#     138008.0,
#     15341487.0,
#     None,
#     None,
#     None],
#    ['2020-02-18',
#     107.2,
#     109.8,
#     107.0,
#     109.6,
#     None,
#     111209.0,
#     12136682.0,
#     None,
#     None,
#     None],
#    ['2020-02-17',
#     108.9,
#     109.1,
#     107.6,
#     108.8,
#     None,
#     71884.0,
#     7784747.5,
#     None,
#     None,
#     None],
#    ['2020-02-14',
#     109.2,
#     110.1,
#     108.2,
#     108.9,
#     None,
#     127710.0,
#     13932329.0,
#     None,
#     None,
#     None],
#    ['2020-02-13',
#     110.0,
#     111.0,
#     107.6,
#     109.5,
#     None,
#     175311.0,
#     19094774.0,
#     None,
#     None,
#     None],
#    ['2020-02-12',
#     112.4,
#     112.4,
#     109.7,
#     110.0,
#     None,
#     153713.0,
#     16973868.0,
#     None,
#     None,
#     None],
#    ['2020-02-11',
#     110.1,
#     113.6,
#     109.3,
#     112.2,
#     None,
#     266600.0,
#     29766104.0,
#     None,
#     None,
#     None],
#    ['2020-02-10',
#     114.0,
#     121.1,
#     107.0,
#     109.4,
#     None,
#     449853.0,
#     50064696.0,
#     None,
#     None,
#     None],
#    ['2020-02-07',
#     116.4,
#     117.4,
#     114.1,
#     114.9,
#     None,
#     158446.0,
#     18250740.0,
#     None,
#     None,
#     None],
#    ['2020-02-06',
#     117.0,
#     117.2,
#     114.7,
#     116.4,
#     None,
#     98097.0,
#     11377620.0,
#     None,
#     None,
#     None],
#    ['2020-02-05',
#     116.4,
#     117.0,
#     115.8,
#     116.1,
#     None,
#     141363.0,
#     16440834.0,
#     None,
#     None,
#     None],
#    ['2020-02-04',
#     112.1,
#     115.7,
#     111.7,
#     115.0,
#     None,
#     214584.0,
#     24603160.0,
#     None,
#     None,
#     None],
#    ['2020-02-03',
#     110.0,
#     112.0,
#     109.3,
#     111.4,
#     None,
#     231387.0,
#     25691706.0,
#     None,
#     None,
#     None],
#    ['2020-01-31',
#     112.5,
#     113.7,
#     110.1,
#     110.5,
#     None,
#     257830.0,
#     28708798.0,
#     None,
#     None,
#     None],
#    ['2020-01-30',
#     116.8,
#     118.0,
#     112.8,
#     113.3,
#     None,
#     198663.0,
#     22749126.0,
#     None,
#     None,
#     None],
#    ['2020-01-29',
#     118.3,
#     118.8,
#     117.4,
#     117.7,
#     None,
#     88563.0,
#     10438738.0,
#     None,
#     None,
#     None],
#    ['2020-01-28',
#     118.8,
#     119.6,
#     115.2,
#     118.1,
#     None,
#     134333.0,
#     15754191.0,
#     None,
#     None,
#     None],
#    ['2020-01-27',
#     119.6,
#     119.7,
#     117.9,
#     118.0,
#     None,
#     110778.0,
#     13126700.0,
#     None,
#     None,
#     None],
#    ['2020-01-24',
#     119.5,
#     120.7,
#     118.6,
#     120.2,
#     None,
#     102713.0,
#     12323204.0,
#     None,
#     None,
#     None],
#    ['2020-01-23',
#     120.2,
#     120.9,
#     118.8,
#     118.8,
#     None,
#     92012.0,
#     11007938.0,
#     None,
#     None,
#     None],
#    ['2020-01-22',
#     120.2,
#     121.1,
#     119.2,
#     119.7,
#     None,
#     74016.0,
#     8885031.0,
#     None,
#     None,
#     None],
#    ['2020-01-21',
#     121.4,
#     121.4,
#     118.9,
#     119.6,
#     None,
#     98600.0,
#     11805317.0,
#     None,
#     None,
#     None],
#    ['2020-01-20',
#     121.2,
#     122.1,
#     120.7,
#     121.4,
#     None,
#     63664.0,
#     7721389.5,
#     None,
#     None,
#     None],
#    ['2020-01-17',
#     119.9,
#     121.1,
#     119.3,
#     120.8,
#     None,
#     63663.0,
#     7671528.0,
#     None,
#     None,
#     None],
#    ['2020-01-16',
#     120.4,
#     120.8,
#     119.0,
#     119.2,
#     None,
#     66065.0,
#     7893356.5,
#     None,
#     None,
#     None],
#    ['2020-01-15',
#     119.5,
#     120.7,
#     119.1,
#     120.0,
#     None,
#     111393.0,
#     13370345.0,
#     None,
#     None,
#     None],
#    ['2020-01-14',
#     117.6,
#     119.5,
#     116.7,
#     119.3,
#     None,
#     105126.0,
#     12492392.0,
#     None,
#     None,
#     None],
#    ['2020-01-13',
#     118.0,
#     118.9,
#     117.0,
#     117.2,
#     None,
#     84067.0,
#     9891618.0,
#     None,
#     None,
#     None],
#    ['2020-01-10',
#     119.6,
#     120.4,
#     117.3,
#     117.5,
#     None,
#     102423.0,
#     12098654.0,
#     None,
#     None,
#     None],
#    ['2020-01-09',
#     118.4,
#     119.8,
#     117.5,
#     119.2,
#     None,
#     134426.0,
#     15973124.0,
#     None,
#     None,
#     None],
#    ['2020-01-08',
#     114.2,
#     116.8,
#     114.0,
#     116.4,
#     None,
#     82884.0,
#     9602366.0,
#     None,
#     None,
#     None],
#    ['2020-01-07',
#     114.4,
#     116.9,
#     114.3,
#     114.9,
#     None,
#     98974.0,
#     11431904.0,
#     None,
#     None,
#     None],
#    ['2020-01-06',
#     112.0,
#     114.3,
#     111.7,
#     114.0,
#     None,
#     95697.0,
#     10844169.0,
#     None,
#     None,
#     None],
#    ['2020-01-03',
#     112.8,
#     113.4,
#     112.0,
#     113.4,
#     None,
#     82304.0,
#     9289987.0,
#     None,
#     None,
#     None],
#    ['2020-01-02',
#     114.0,
#     114.9,
#     112.7,
#     113.8,
#     None,
#     143464.0,
#     16291666.0,
#     None,
#     None,
#     None],
#    ['2019-12-30',
#     116.4,
#     116.5,
#     113.7,
#     113.7,
#     None,
#     60915.0,
#     6979033.0,
#     None,
#     None,
#     None],
#    ['2019-12-27',
#     116.0,
#     116.3,
#     115.0,
#     116.3,
#     None,
#     62154.0,
#     7208475.5,
#     None,
#     None,
#     None],
#    ['2019-12-23',
#     115.0,
#     116.2,
#     114.6,
#     114.9,
#     None,
#     66229.0,
#     7626266.1,
#     None,
#     None,
#     None],
#    ['2019-12-20',
#     115.9,
#     116.7,
#     114.4,
#     114.6,
#     None,
#     185866.0,
#     21368077.0,
#     None,
#     None,
#     None],
#    ['2019-12-19',
#     115.8,
#     116.2,
#     114.9,
#     115.6,
#     None,
#     124269.0,
#     14364060.2,
#     None,
#     None,
#     None],
#    ['2019-12-18',
#     115.4,
#     115.9,
#     114.3,
#     115.5,
#     None,
#     124036.0,
#     14308979.8,
#     None,
#     None,
#     None],
#    ['2019-12-17',
#     113.4,
#     115.6,
#     113.1,
#     115.6,
#     None,
#     198741.0,
#     22797197.4,
#     None,
#     None,
#     None],
#    ['2019-12-16',
#     111.9,
#     113.5,
#     111.1,
#     112.9,
#     None,
#     123873.0,
#     13933520.7,
#     None,
#     None,
#     None],
#    ['2019-12-13',
#     113.0,
#     113.0,
#     110.5,
#     111.3,
#     None,
#     115681.0,
#     12875607.7,
#     None,
#     None,
#     None],
#    ['2019-12-12',
#     113.0,
#     113.9,
#     111.4,
#     111.9,
#     None,
#     169064.0,
#     18990658.0,
#     None,
#     None,
#     None],
#    ['2019-12-11',
#     113.8,
#     113.8,
#     110.9,
#     112.0,
#     None,
#     149438.0,
#     16744868.0,
#     None,
#     None,
#     None],
#    ['2019-12-10',
#     114.0,
#     115.3,
#     110.0,
#     113.0,
#     None,
#     219116.0,
#     24654700.0,
#     None,
#     None,
#     None],
#    ['2019-12-09',
#     105.1,
#     114.7,
#     105.1,
#     114.3,
#     None,
#     405833.0,
#     45488588.0,
#     None,
#     None,
#     None],
#    ['2019-12-06',
#     106.6,
#     106.6,
#     99.6,
#     103.1,
#     None,
#     561633.0,
#     57520904.0,
#     None,
#     None,
#     None],
#    ['2019-12-05',
#     110.1,
#     110.3,
#     109.2,
#     110.1,
#     None,
#     69911.0,
#     7687537.5,
#     None,
#     None,
#     None],
#    ['2019-12-04',
#     108.6,
#     110.4,
#     108.5,
#     109.6,
#     None,
#     91446.0,
#     10015437.0,
#     None,
#     None,
#     None],
#    ['2019-12-03',
#     107.7,
#     110.1,
#     107.3,
#     108.9,
#     None,
#     130237.0,
#     14162319.0,
#     None,
#     None,
#     None],
#    ['2019-12-02',
#     111.0,
#     111.4,
#     107.2,
#     107.6,
#     None,
#     144610.0,
#     15685797.0,
#     None,
#     None,
#     None],
#    ['2019-11-29',
#     108.2,
#     112.7,
#     108.1,
#     111.0,
#     None,
#     168617.0,
#     18731904.0,
#     None,
#     None,
#     None],
#    ['2019-11-28',
#     109.1,
#     109.1,
#     107.5,
#     108.1,
#     None,
#     44677.0,
#     4827719.0,
#     None,
#     None,
#     None],
#    ['2019-11-27',
#     109.9,
#     110.0,
#     108.0,
#     108.6,
#     None,
#     80332.0,
#     8731068.0,
#     None,
#     None,
#     None],
#    ['2019-11-26',
#     108.6,
#     110.0,
#     107.5,
#     109.5,
#     None,
#     280313.0,
#     30604384.0,
#     None,
#     None,
#     None],
#    ['2019-11-25',
#     107.4,
#     109.1,
#     106.4,
#     108.1,
#     None,
#     101435.0,
#     10965700.0,
#     None,
#     None,
#     None],
#    ['2019-11-22',
#     106.1,
#     107.1,
#     105.9,
#     106.6,
#     None,
#     116214.0,
#     12391521.0,
#     None,
#     None,
#     None],
#    ['2019-11-21',
#     105.5,
#     106.9,
#     104.6,
#     106.0,
#     None,
#     135671.0,
#     14383910.0,
#     None,
#     None,
#     None],
#    ['2019-11-20',
#     104.5,
#     107.4,
#     104.2,
#     106.0,
#     None,
#     148853.0,
#     15777142.0,
#     None,
#     None,
#     None],
#    ['2019-11-19',
#     104.9,
#     105.3,
#     103.9,
#     104.5,
#     None,
#     86228.0,
#     9006823.0,
#     None,
#     None,
#     None],
#    ['2019-11-18',
#     104.0,
#     105.5,
#     103.8,
#     104.8,
#     None,
#     100901.0,
#     10565891.0,
#     None,
#     None,
#     None],
#    ['2019-11-15',
#     102.0,
#     104.1,
#     101.9,
#     104.0,
#     None,
#     102061.0,
#     10555093.0,
#     None,
#     None,
#     None],
#    ['2019-11-14',
#     102.6,
#     102.9,
#     100.4,
#     101.6,
#     None,
#     89727.0,
#     9123501.0,
#     None,
#     None,
#     None],
#    ['2019-11-13',
#     100.4,
#     102.3,
#     100.4,
#     102.3,
#     None,
#     106648.0,
#     10854356.0,
#     None,
#     None,
#     None],
#    ['2019-11-12',
#     101.1,
#     102.0,
#     98.9,
#     101.0,
#     None,
#     128193.0,
#     12877095.0,
#     None,
#     None,
#     None],
#    ['2019-11-11',
#     102.1,
#     103.8,
#     100.6,
#     100.8,
#     None,
#     95512.0,
#     9684446.0,
#     None,
#     None,
#     None],
#    ['2019-11-08',
#     101.8,
#     102.8,
#     100.2,
#     101.8,
#     None,
#     127304.0,
#     12917154.0,
#     None,
#     None,
#     None],
#    ['2019-11-07',
#     103.7,
#     104.1,
#     101.2,
#     102.2,
#     None,
#     145112.0,
#     14855882.0,
#     None,
#     None,
#     None],
#    ['2019-11-06',
#     100.5,
#     103.2,
#     99.4,
#     103.2,
#     None,
#     132904.0,
#     13585029.0,
#     None,
#     None,
#     None],
#    ['2019-11-05',
#     99.65,
#     100.7,
#     98.4,
#     100.3,
#     None,
#     138382.0,
#     13834720.0,
#     None,
#     None,
#     None],
#    ['2019-11-04',
#     98.95,
#     100.2,
#     97.1,
#     99.35,
#     None,
#     140821.0,
#     13931740.0,
#     None,
#     None,
#     None],
#    ['2019-11-01',
#     98.5,
#     99.65,
#     98.15,
#     98.65,
#     None,
#     84471.0,
#     8332533.0,
#     None,
#     None,
#     None],
#    ['2019-10-31',
#     98.05,
#     99.15,
#     97.75,
#     97.75,
#     None,
#     105779.0,
#     10379837.0,
#     None,
#     None,
#     None],
#    ['2019-10-30',
#     96.45,
#     98.85,
#     96.0,
#     98.05,
#     None,
#     101101.0,
#     9910827.0,
#     None,
#     None,
#     None],
#    ['2019-10-29',
#     95.5,
#     96.55,
#     94.45,
#     96.1,
#     None,
#     113338.0,
#     10820482.0,
#     None,
#     None,
#     None],
#    ['2019-10-28',
#     97.7,
#     97.95,
#     95.35,
#     95.85,
#     None,
#     113497.0,
#     10914759.0,
#     None,
#     None,
#     None],
#    ['2019-10-25',
#     96.1,
#     97.55,
#     95.4,
#     97.0,
#     None,
#     155040.0,
#     14968588.0,
#     None,
#     None,
#     None],
#    ['2019-10-24',
#     94.15,
#     96.4,
#     92.8,
#     96.0,
#     None,
#     275194.0,
#     26191594.0,
#     None,
#     None,
#     None],
#    ['2019-10-23',
#     100.4,
#     100.8,
#     89.35,
#     92.55,
#     None,
#     605001.0,
#     56532324.0,
#     None,
#     None,
#     None],
#    ['2019-10-22',
#     101.7,
#     102.7,
#     99.9,
#     101.5,
#     None,
#     90905.0,
#     9234451.0,
#     None,
#     None,
#     None],
#    ['2019-10-21',
#     103.7,
#     104.1,
#     100.7,
#     101.4,
#     None,
#     108567.0,
#     11048451.0,
#     None,
#     None,
#     None],
#    ['2019-10-18',
#     103.9,
#     104.7,
#     103.2,
#     103.7,
#     None,
#     73189.0,
#     7598035.5,
#     None,
#     None,
#     None],
#    ['2019-10-17',
#     103.2,
#     104.5,
#     102.9,
#     103.8,
#     None,
#     115138.0,
#     11944767.0,
#     None,
#     None,
#     None],
#    ['2019-10-16',
#     104.1,
#     104.7,
#     101.4,
#     103.2,
#     None,
#     116588.0,
#     12026270.0,
#     None,
#     None,
#     None],
#    ['2019-10-15',
#     104.0,
#     104.8,
#     102.8,
#     103.9,
#     None,
#     79933.0,
#     8308760.5,
#     None,
#     None,
#     None],
#    ['2019-10-14',
#     102.4,
#     103.3,
#     101.1,
#     103.2,
#     None,
#     83291.0,
#     8556893.0,
#     None,
#     None,
#     None],
#    ['2019-10-11',
#     103.0,
#     103.7,
#     101.1,
#     102.4,
#     None,
#     124625.0,
#     12751459.0,
#     None,
#     None,
#     None],
#    ['2019-10-10',
#     107.0,
#     107.0,
#     101.9,
#     102.5,
#     None,
#     204279.0,
#     21027192.0,
#     None,
#     None,
#     None],
#    ['2019-10-09',
#     106.3,
#     107.7,
#     105.5,
#     107.0,
#     None,
#     94098.0,
#     10050758.0,
#     None,
#     None,
#     None],
#    ['2019-10-08',
#     109.5,
#     109.9,
#     106.3,
#     106.5,
#     None,
#     97553.0,
#     10483011.0,
#     None,
#     None,
#     None],
#    ['2019-10-07',
#     108.5,
#     110.3,
#     107.5,
#     108.8,
#     None,
#     97154.0,
#     10561664.0,
#     None,
#     None,
#     None],
#    ['2019-10-04',
#     105.0,
#     109.5,
#     104.4,
#     108.2,
#     None,
#     198283.0,
#     21355196.0,
#     None,
#     None,
#     None],
#    ['2019-10-02',
#     104.9,
#     111.5,
#     103.7,
#     105.6,
#     None,
#     342563.0,
#     36835516.0,
#     None,
#     None,
#     None],
#    ['2019-10-01',
#     105.3,
#     105.9,
#     103.8,
#     104.8,
#     None,
#     132282.0,
#     13861037.0,
#     None,
#     None,
#     None],
#    ['2019-09-30',
#     104.2,
#     105.1,
#     102.7,
#     104.6,
#     None,
#     92395.0,
#     9628660.0,
#     None,
#     None,
#     None],
#    ['2019-09-27',
#     103.7,
#     104.0,
#     102.5,
#     103.5,
#     None,
#     74036.0,
#     7656140.5,
#     None,
#     None,
#     None],
#    ['2019-09-26',
#     102.3,
#     104.3,
#     101.5,
#     103.8,
#     None,
#     78159.0,
#     8096350.5,
#     None,
#     None,
#     None],
#    ['2019-09-25',
#     104.0,
#     104.2,
#     100.1,
#     101.5,
#     None,
#     169893.0,
#     17234866.0,
#     None,
#     None,
#     None],
#    ['2019-09-24',
#     103.6,
#     105.2,
#     103.6,
#     105.0,
#     None,
#     61623.0,
#     6452339.0,
#     None,
#     None,
#     None],
#    ['2019-09-23',
#     103.1,
#     105.1,
#     102.8,
#     103.8,
#     None,
#     69848.0,
#     7263194.5,
#     None,
#     None,
#     None],
#    ['2019-09-20',
#     104.9,
#     105.0,
#     101.8,
#     103.3,
#     None,
#     198709.0,
#     20505680.0,
#     None,
#     None,
#     None],
#    ['2019-09-19',
#     102.7,
#     104.8,
#     102.1,
#     104.5,
#     None,
#     125080.0,
#     13001448.0,
#     None,
#     None,
#     None],
#    ['2019-09-18',
#     102.4,
#     104.0,
#     102.2,
#     103.3,
#     None,
#     117228.0,
#     12104268.0,
#     None,
#     None,
#     None],
#    ['2019-09-17',
#     99.7,
#     102.1,
#     98.7,
#     102.0,
#     None,
#     135793.0,
#     13767140.0,
#     None,
#     None,
#     None],
#    ['2019-09-16',
#     99.0,
#     99.75,
#     97.85,
#     99.35,
#     None,
#     112585.0,
#     11171601.0,
#     None,
#     None,
#     None],
#    ['2019-09-13',
#     102.2,
#     102.3,
#     98.1,
#     98.9,
#     None,
#     130746.0,
#     12958266.0,
#     None,
#     None,
#     None],
#    ['2019-09-12',
#     101.9,
#     102.8,
#     100.6,
#     101.9,
#     None,
#     119437.0,
#     12145270.0,
#     None,
#     None,
#     None],
#    ['2019-09-11',
#     100.7,
#     101.7,
#     99.0,
#     101.0,
#     None,
#     171872.0,
#     17257904.0,
#     None,
#     None,
#     None],
#    ['2019-09-10',
#     105.5,
#     105.5,
#     99.75,
#     100.5,
#     None,
#     271425.0,
#     27466300.0,
#     None,
#     None,
#     None],
#    ['2019-09-09',
#     109.1,
#     109.7,
#     105.7,
#     105.7,
#     None,
#     86187.0,
#     9187726.0,
#     None,
#     None,
#     None],
#    ['2019-09-06',
#     106.1,
#     109.6,
#     106.0,
#     108.7,
#     None,
#     101489.0,
#     11006270.0,
#     None,
#     None,
#     None],
#    ['2019-09-05',
#     109.0,
#     110.9,
#     106.2,
#     106.4,
#     None,
#     91265.0,
#     9771449.0,
#     None,
#     None,
#     None],
#    ['2019-09-04',
#     107.4,
#     109.1,
#     107.1,
#     108.3,
#     None,
#     94641.0,
#     10247516.0,
#     None,
#     None,
#     None],
#    ['2019-09-03',
#     107.4,
#     107.7,
#     105.9,
#     107.0,
#     None,
#     105012.0,
#     11237644.0,
#     None,
#     None,
#     None],
#    ['2019-09-02',
#     104.5,
#     107.5,
#     104.5,
#     106.7,
#     None,
#     91105.0,
#     9729992.0,
#     None,
#     None,
#     None],
#    ['2019-08-30',
#     105.7,
#     105.7,
#     104.4,
#     104.9,
#     None,
#     120743.0,
#     12667534.0,
#     None,
#     None,
#     None],
#    ['2019-08-29',
#     107.0,
#     107.6,
#     105.7,
#     105.7,
#     None,
#     87491.0,
#     9291293.0,
#     None,
#     None,
#     None],
#    ['2019-08-28',
#     105.0,
#     107.0,
#     104.4,
#     106.6,
#     None,
#     110155.0,
#     11686854.0,
#     None,
#     None,
#     None],
#    ['2019-08-27',
#     103.0,
#     105.2,
#     102.6,
#     105.1,
#     None,
#     165727.0,
#     17367660.0,
#     None,
#     None,
#     None],
#    ['2019-08-26',
#     102.8,
#     103.1,
#     101.4,
#     103.0,
#     None,
#     63857.0,
#     6556853.5,
#     None,
#     None,
#     None],
#    ['2019-08-23',
#     103.4,
#     105.0,
#     102.8,
#     102.8,
#     None,
#     97791.0,
#     10120408.0,
#     None,
#     None,
#     None],
#    ['2019-08-22',
#     104.6,
#     106.7,
#     103.3,
#     103.3,
#     None,
#     140365.0,
#     14598704.0,
#     None,
#     None,
#     None],
#    ['2019-08-21',
#     101.2,
#     104.3,
#     100.9,
#     103.6,
#     None,
#     111234.0,
#     11480594.0,
#     None,
#     None,
#     None],
#    ['2019-08-20',
#     101.4,
#     102.9,
#     100.5,
#     100.6,
#     None,
#     111166.0,
#     11268671.0,
#     None,
#     None,
#     None],
#    ['2019-08-19',
#     100.3,
#     101.3,
#     98.2,
#     101.2,
#     None,
#     131618.0,
#     13223834.0,
#     None,
#     None,
#     None],
#    ['2019-08-16',
#     98.35,
#     99.4,
#     97.15,
#     99.3,
#     None,
#     106762.0,
#     10549874.0,
#     None,
#     None,
#     None],
#    ['2019-08-15',
#     100.2,
#     101.0,
#     96.45,
#     97.9,
#     None,
#     133330.0,
#     13092741.0,
#     None,
#     None,
#     None],
#    ['2019-08-14',
#     99.55,
#     103.1,
#     99.3,
#     100.8,
#     None,
#     192752.0,
#     19524066.0,
#     None,
#     None,
#     None],
#    ['2019-08-13',
#     99.05,
#     99.6,
#     97.55,
#     98.75,
#     None,
#     113097.0,
#     11171934.0,
#     None,
#     None,
#     None],
#    ['2019-08-12',
#     100.0,
#     101.6,
#     98.2,
#     98.95,
#     None,
#     111146.0,
#     11031779.0,
#     None,
#     None,
#     None],
#    ['2019-08-09',
#     99.2,
#     104.3,
#     94.4,
#     99.05,
#     None,
#     217386.0,
#     21511178.0,
#     None,
#     None,
#     None],
#    ['2019-08-08',
#     95.35,
#     95.35,
#     94.2,
#     95.1,
#     None,
#     110482.0,
#     10474803.0,
#     None,
#     None,
#     None],
#    ['2019-08-07',
#     94.15,
#     95.05,
#     93.05,
#     93.9,
#     None,
#     119157.0,
#     11200026.0,
#     None,
#     None,
#     None],
#    ['2019-08-06',
#     93.65,
#     95.15,
#     93.25,
#     93.25,
#     None,
#     119714.0,
#     11218618.0,
#     None,
#     None,
#     None],
#    ['2019-08-05',
#     96.35,
#     96.35,
#     92.75,
#     94.05,
#     None,
#     232748.0,
#     21909462.0,
#     None,
#     None,
#     None],
#    ['2019-08-02',
#     99.95,
#     100.8,
#     97.25,
#     97.25,
#     None,
#     124704.0,
#     12224533.0,
#     None,
#     None,
#     None],
#    ['2019-08-01',
#     99.6,
#     100.7,
#     99.3,
#     100.5,
#     None,
#     102399.0,
#     10267086.0,
#     None,
#     None,
#     None],
#    ['2019-07-31',
#     99.0,
#     99.75,
#     98.35,
#     99.45,
#     None,
#     106057.0,
#     10535986.0,
#     None,
#     None,
#     None],
#    ['2019-07-30',
#     100.3,
#     100.4,
#     98.85,
#     99.2,
#     None,
#     117634.0,
#     11712535.0,
#     None,
#     None,
#     None],
#    ['2019-07-29',
#     98.95,
#     100.4,
#     98.75,
#     99.85,
#     None,
#     104305.0,
#     10408428.0,
#     None,
#     None,
#     None],
#    ['2019-07-26',
#     96.5,
#     99.3,
#     96.15,
#     99.0,
#     None,
#     116311.0,
#     11474417.0,
#     None,
#     None,
#     None],
#    ['2019-07-25',
#     98.35,
#     99.5,
#     96.9,
#     97.25,
#     None,
#     84809.0,
#     8301676.5,
#     None,
#     None,
#     None],
#    ['2019-07-24',
#     98.45,
#     98.95,
#     96.65,
#     97.5,
#     None,
#     111280.0,
#     10851049.0,
#     None,
#     None,
#     None],
#    ['2019-07-23',
#     97.2,
#     98.2,
#     97.05,
#     98.1,
#     None,
#     91724.0,
#     8971253.0,
#     None,
#     None,
#     None],
#    ['2019-07-22',
#     97.7,
#     98.05,
#     96.45,
#     97.1,
#     None,
#     106134.0,
#     10314239.0,
#     None,
#     None,
#     None],
#    ['2019-07-19',
#     98.0,
#     98.35,
#     96.8,
#     97.5,
#     None,
#     110757.0,
#     10795196.0,
#     None,
#     None,
#     None],
#    ['2019-07-18',
#     97.05,
#     98.5,
#     96.35,
#     97.9,
#     None,
#     138280.0,
#     13508944.0,
#     None,
#     None,
#     None],
#    ['2019-07-17',
#     95.3,
#     98.6,
#     94.6,
#     97.3,
#     None,
#     221229.0,
#     21534144.0,
#     None,
#     None,
#     None],
#    ['2019-07-16',
#     93.0,
#     98.6,
#     92.65,
#     95.3,
#     None,
#     278130.0,
#     26587740.0,
#     None,
#     None,
#     None],
#    ['2019-07-15',
#     84.8,
#     94.1,
#     84.8,
#     93.6,
#     None,
#     481793.0,
#     43283072.0,
#     None,
#     None,
#     None],
#    ['2019-07-12',
#     86.15,
#     86.2,
#     84.45,
#     84.95,
#     None,
#     111137.0,
#     9448958.0,
#     None,
#     None,
#     None],
#    ['2019-07-11',
#     85.7,
#     87.15,
#     85.65,
#     86.15,
#     None,
#     162794.0,
#     14041185.0,
#     None,
#     None,
#     None],
#    ['2019-07-10',
#     86.05,
#     86.55,
#     84.15,
#     85.75,
#     None,
#     116226.0,
#     9947223.0,
#     None,
#     None,
#     None],
#    ['2019-07-09',
#     85.4,
#     87.6,
#     85.4,
#     86.2,
#     None,
#     104420.0,
#     9026189.0,
#     None,
#     None,
#     None],
#    ['2019-07-08',
#     85.75,
#     86.4,
#     85.2,
#     85.9,
#     None,
#     63967.0,
#     5495242.5,
#     None,
#     None,
#     None],
#    ['2019-07-05',
#     87.95,
#     88.25,
#     84.9,
#     85.95,
#     None,
#     124957.0,
#     10782292.0,
#     None,
#     None,
#     None],
#    ['2019-07-04',
#     88.05,
#     88.3,
#     86.9,
#     88.05,
#     None,
#     98273.0,
#     8621586.0,
#     None,
#     None,
#     None],
#    ['2019-07-03',
#     86.6,
#     88.45,
#     86.45,
#     88.3,
#     None,
#     130283.0,
#     11450014.0,
#     None,
#     None,
#     None],
#    ['2019-07-02',
#     85.95,
#     86.5,
#     85.35,
#     86.5,
#     None,
#     150270.0,
#     12952523.0,
#     None,
#     None,
#     None],
#    ['2019-07-01',
#     88.6,
#     88.6,
#     85.15,
# ...
#     4498956.0,
#     None,
#     None,
#     None],
#    ['2018-06-13',
#     None,
#     61.85,
#     61.3,
#     61.55,
#     None,
#     77752.0,
#     4786379.0,
#     None,
#     None,
#     None],
#    ['2018-06-12',
#     None,
#     62.05,
#     60.9,
#     61.2,
#     None,
#     62494.0,
#     3830707.0,
#     None,
#     None,
#     None],
#    ['2018-06-11',
#     None,
#     61.5,
#     60.85,
#     61.35,
#     None,
#     56533.0,
#     3461580.0,
#     None,
#     None,
#     None],
#    ['2018-06-07',
#     None,
#     60.85,
#     59.65,
#     59.95,
#     None,
#     84215.0,
#     5062604.0,
#     None,
#     None,
#     None],
#    ['2018-06-06',
#     None,
#     60.75,
#     59.45,
#     60.55,
#     None,
#     119380.0,
#     7202424.0,
#     None,
#     None,
#     None],
#    ['2018-06-05',
#     None,
#     59.75,
#     58.95,
#     59.55,
#     None,
#     98799.0,
#     5871733.0,
#     None,
#     None,
#     None],
#    ['2018-06-04',
#     None,
#     59.45,
#     58.7,
#     59.2,
#     None,
#     99669.0,
#     5893346.0,
#     None,
#     None,
#     None],
#    ['2018-06-01',
#     None,
#     59.35,
#     56.9,
#     58.9,
#     None,
#     121922.0,
#     7149977.0,
#     None,
#     None,
#     None],
#    ['2018-05-31',
#     None,
#     59.6,
#     58.75,
#     59.15,
#     None,
#     108504.0,
#     6416256.0,
#     None,
#     None,
#     None],
#    ['2018-05-30',
#     None,
#     60.25,
#     58.65,
#     58.7,
#     None,
#     97364.0,
#     5758058.0,
#     None,
#     None,
#     None],
#    ['2018-05-28',
#     None,
#     61.3,
#     60.2,
#     61.25,
#     None,
#     88908.0,
#     5407976.0,
#     None,
#     None,
#     None],
#    ['2018-05-25',
#     None,
#     60.25,
#     58.5,
#     60.25,
#     None,
#     99172.0,
#     5921845.0,
#     None,
#     None,
#     None],
#    ['2018-05-24',
#     None,
#     58.8,
#     57.7,
#     58.5,
#     None,
#     72723.0,
#     4250331.0,
#     None,
#     None,
#     None],
#    ['2018-05-23',
#     None,
#     58.05,
#     57.0,
#     57.9,
#     None,
#     46697.0,
#     2690820.0,
#     None,
#     None,
#     None],
#    ['2018-05-22',
#     None,
#     58.55,
#     57.65,
#     58.05,
#     None,
#     76281.0,
#     4428520.0,
#     None,
#     None,
#     None],
#    ['2018-05-18',
#     None,
#     59.0,
#     57.1,
#     57.95,
#     None,
#     81077.0,
#     4707479.0,
#     None,
#     None,
#     None],
#    ['2018-05-17',
#     None,
#     57.35,
#     56.7,
#     57.25,
#     None,
#     69080.0,
#     3946079.0,
#     None,
#     None,
#     None],
#    ['2018-05-16',
#     None,
#     58.05,
#     56.9,
#     57.0,
#     None,
#     56288.0,
#     3228216.0,
#     None,
#     None,
#     None],
#    ['2018-05-15',
#     None,
#     57.65,
#     55.75,
#     57.0,
#     None,
#     100626.0,
#     5724266.0,
#     None,
#     None,
#     None],
#    ['2018-05-14',
#     None,
#     57.95,
#     57.15,
#     57.8,
#     None,
#     50399.0,
#     2905596.0,
#     None,
#     None,
#     None],
#    ['2018-05-11',
#     None,
#     58.15,
#     56.95,
#     57.35,
#     None,
#     63082.0,
#     3621924.0,
#     None,
#     None,
#     None],
#    ['2018-05-10',
#     None,
#     58.15,
#     57.5,
#     58.15,
#     None,
#     20795.0,
#     1206105.0,
#     None,
#     None,
#     None],
#    ['2018-05-09',
#     None,
#     57.6,
#     56.75,
#     57.6,
#     None,
#     52426.0,
#     3002890.0,
#     None,
#     None,
#     None],
#    ['2018-05-08',
#     None,
#     59.15,
#     57.35,
#     57.35,
#     None,
#     64959.0,
#     3738329.0,
#     None,
#     None,
#     None],
#    ['2018-05-07',
#     None,
#     58.95,
#     57.4,
#     58.95,
#     None,
#     52378.0,
#     3060029.0,
#     None,
#     None,
#     None],
#    ['2018-05-04',
#     None,
#     57.9,
#     56.95,
#     57.15,
#     None,
#     52985.0,
#     3032353.0,
#     None,
#     None,
#     None],
#    ['2018-05-03',
#     None,
#     57.6,
#     56.8,
#     57.1,
#     None,
#     60236.0,
#     3444406.0,
#     None,
#     None,
#     None],
#    ['2018-05-02',
#     None,
#     58.1,
#     56.4,
#     57.45,
#     None,
#     88108.0,
#     5054341.0,
#     None,
#     None,
#     None],
#    ['2018-04-30',
#     None,
#     56.45,
#     56.0,
#     56.3,
#     None,
#     58326.0,
#     3280897.0,
#     None,
#     None,
#     None],
#    ['2018-04-27',
#     None,
#     56.85,
#     55.05,
#     56.0,
#     None,
#     86375.0,
#     4847905.0,
#     None,
#     None,
#     None],
#    ['2018-04-26',
#     None,
#     55.15,
#     54.3,
#     55.05,
#     None,
#     51209.0,
#     2810881.0,
#     None,
#     None,
#     None],
#    ['2018-04-25',
#     None,
#     54.95,
#     54.0,
#     54.75,
#     None,
#     91616.0,
#     5003149.0,
#     None,
#     None,
#     None],
#    ['2018-04-24',
#     None,
#     54.75,
#     54.15,
#     54.6,
#     None,
#     59651.0,
#     3252235.0,
#     None,
#     None,
#     None],
#    ['2018-04-23',
#     None,
#     54.9,
#     53.75,
#     54.7,
#     None,
#     67059.0,
#     3656093.0,
#     None,
#     None,
#     None],
#    ['2018-04-20',
#     None,
#     54.1,
#     53.55,
#     53.9,
#     None,
#     56023.0,
#     3021011.0,
#     None,
#     None,
#     None],
#    ['2018-04-19',
#     None,
#     54.1,
#     52.8,
#     53.9,
#     None,
#     65723.0,
#     3533700.0,
#     None,
#     None,
#     None],
#    ['2018-04-18',
#     None,
#     53.25,
#     52.2,
#     53.25,
#     None,
#     72894.0,
#     3863971.0,
#     None,
#     None,
#     None],
#    ['2018-04-17',
#     None,
#     52.25,
#     51.65,
#     52.0,
#     None,
#     57127.0,
#     2971940.0,
#     None,
#     None,
#     None],
#    ['2018-04-16',
#     None,
#     52.4,
#     51.05,
#     51.8,
#     None,
#     125663.0,
#     6513055.0,
#     None,
#     None,
#     None],
#    ['2018-04-13',
#     None,
#     52.95,
#     51.7,
#     52.5,
#     None,
#     59575.0,
#     3122819.0,
#     None,
#     None,
#     None],
#    ['2018-04-12',
#     None,
#     52.2,
#     50.85,
#     52.0,
#     None,
#     77912.0,
#     4033804.0,
#     None,
#     None,
#     None],
#    ['2018-04-11',
#     None,
#     52.2,
#     51.15,
#     51.3,
#     None,
#     94078.0,
#     4884841.0,
#     None,
#     None,
#     None],
#    ['2018-04-10',
#     None,
#     53.55,
#     52.1,
#     52.2,
#     None,
#     117708.0,
#     6192817.0,
#     None,
#     None,
#     None],
#    ['2018-04-09',
#     None,
#     53.0,
#     51.75,
#     53.0,
#     None,
#     72459.0,
#     3812927.0,
#     None,
#     None,
#     None],
#    ['2018-04-06',
#     None,
#     51.75,
#     51.15,
#     51.7,
#     None,
#     37429.0,
#     1931216.0,
#     None,
#     None,
#     None],
#    ['2018-04-05',
#     None,
#     51.8,
#     51.0,
#     51.65,
#     None,
#     45012.0,
#     2317907.0,
#     None,
#     None,
#     None],
#    ['2018-04-04',
#     None,
#     51.8,
#     50.75,
#     50.9,
#     None,
#     69739.0,
#     3559486.0,
#     None,
#     None,
#     None],
#    ['2018-04-03',
#     None,
#     51.7,
#     50.8,
#     51.65,
#     None,
#     92025.0,
#     4734817.0,
#     None,
#     None,
#     None],
#    ['2018-03-29',
#     None,
#     52.15,
#     51.15,
#     51.85,
#     None,
#     56160.0,
#     2908967.0,
#     None,
#     None,
#     None],
#    ['2018-03-28',
#     None,
#     52.1,
#     51.0,
#     51.55,
#     None,
#     66175.0,
#     3412277.0,
#     None,
#     None,
#     None],
#    ['2018-03-27',
#     None,
#     52.1,
#     50.35,
#     51.7,
#     None,
#     89089.0,
#     4582469.0,
#     None,
#     None,
#     None],
#    ['2018-03-26',
#     None,
#     50.95,
#     49.62,
#     50.05,
#     None,
#     80836.0,
#     4062036.0,
#     None,
#     None,
#     None],
#    ['2018-03-23',
#     None,
#     49.68,
#     48.6,
#     49.42,
#     None,
#     90793.0,
#     4466193.0,
#     None,
#     None,
#     None],
#    ['2018-03-22',
#     None,
#     49.7,
#     49.28,
#     49.6,
#     None,
#     83655.0,
#     4141232.0,
#     None,
#     None,
#     None],
#    ['2018-03-21',
#     None,
#     50.1,
#     49.48,
#     49.56,
#     None,
#     43165.0,
#     2143464.0,
#     None,
#     None,
#     None],
#    ['2018-03-20',
#     None,
#     50.05,
#     49.44,
#     50.0,
#     None,
#     46223.0,
#     2304364.0,
#     None,
#     None,
#     None],
#    ['2018-03-19',
#     None,
#     49.88,
#     48.9,
#     49.5,
#     None,
#     66792.0,
#     3303500.0,
#     None,
#     None,
#     None],
#    ['2018-03-16',
#     None,
#     50.55,
#     49.22,
#     49.22,
#     None,
#     352062.0,
#     17355294.0,
#     None,
#     None,
#     None],
#    ['2018-03-15',
#     None,
#     50.4,
#     49.4,
#     50.2,
#     None,
#     47455.0,
#     2374579.0,
#     None,
#     None,
#     None],
#    ['2018-03-14',
#     None,
#     50.5,
#     49.84,
#     50.0,
#     None,
#     56492.0,
#     2832056.0,
#     None,
#     None,
#     None],
#    ['2018-03-13',
#     None,
#     52.15,
#     50.3,
#     50.4,
#     None,
#     86809.0,
#     4435040.0,
#     None,
#     None,
#     None],
#    ['2018-03-12',
#     None,
#     51.8,
#     50.6,
#     51.7,
#     None,
#     86202.0,
#     4434869.0,
#     None,
#     None,
#     None],
#    ['2018-03-09',
#     None,
#     50.7,
#     50.05,
#     50.5,
#     None,
#     66937.0,
#     3376280.0,
#     None,
#     None,
#     None],
#    ['2018-03-08',
#     None,
#     50.4,
#     49.48,
#     50.25,
#     None,
#     68085.0,
#     3406641.0,
#     None,
#     None,
#     None],
#    ['2018-03-07',
#     None,
#     49.68,
#     48.7,
#     49.56,
#     None,
#     95964.0,
#     4731213.0,
#     None,
#     None,
#     None],
#    ['2018-03-06',
#     None,
#     50.05,
#     49.26,
#     49.58,
#     None,
#     108000.0,
#     5352665.0,
#     None,
#     None,
#     None],
#    ['2018-03-05',
#     None,
#     49.56,
#     48.5,
#     49.22,
#     None,
#     67895.0,
#     3345047.0,
#     None,
#     None,
#     None],
#    ['2018-03-02',
#     None,
#     49.7,
#     48.94,
#     49.02,
#     None,
#     77271.0,
#     3803033.0,
#     None,
#     None,
#     None],
#    ['2018-03-01',
#     None,
#     50.8,
#     50.05,
#     50.25,
#     None,
#     121721.0,
#     6130791.0,
#     None,
#     None,
#     None],
#    ['2018-02-28',
#     None,
#     51.2,
#     50.35,
#     50.8,
#     None,
#     51766.0,
#     2633558.0,
#     None,
#     None,
#     None],
#    ['2018-02-27',
#     None,
#     51.25,
#     50.05,
#     50.8,
#     None,
#     91014.0,
#     4602394.0,
#     None,
#     None,
#     None],
#    ['2018-02-26',
#     None,
#     51.3,
#     49.9,
#     51.15,
#     None,
#     70849.0,
#     3602935.0,
#     None,
#     None,
#     None],
#    ['2018-02-23',
#     None,
#     50.65,
#     49.62,
#     50.15,
#     None,
#     85529.0,
#     4282416.0,
#     None,
#     None,
#     None],
#    ['2018-02-22',
#     None,
#     50.5,
#     49.04,
#     50.3,
#     None,
#     78981.0,
#     3950282.0,
#     None,
#     None,
#     None],
#    ['2018-02-21',
#     None,
#     49.78,
#     49.08,
#     49.72,
#     None,
#     54366.0,
#     2695174.0,
#     None,
#     None,
#     None],
#    ['2018-02-20',
#     None,
#     50.35,
#     49.62,
#     49.98,
#     None,
#     72611.0,
#     3625953.0,
#     None,
#     None,
#     None],
#    ['2018-02-19',
#     None,
#     50.8,
#     49.72,
#     49.78,
#     None,
#     63379.0,
#     3166398.0,
#     None,
#     None,
#     None],
#    ['2018-02-16',
#     None,
#     51.0,
#     49.38,
#     50.75,
#     None,
#     85521.0,
#     4317347.0,
#     None,
#     None,
#     None],
#    ['2018-02-15',
#     None,
#     49.96,
#     48.88,
#     49.34,
#     None,
#     98735.0,
#     4867477.0,
#     None,
#     None,
#     None],
#    ['2018-02-14',
#     None,
#     49.66,
#     48.6,
#     49.48,
#     None,
#     67429.0,
#     3328497.0,
#     None,
#     None,
#     None],
#    ['2018-02-13',
#     None,
#     50.05,
#     48.82,
#     48.88,
#     None,
#     82639.0,
#     4062581.0,
#     None,
#     None,
#     None],
#    ['2018-02-12',
#     None,
#     50.6,
#     47.38,
#     49.76,
#     None,
#     115700.0,
#     5741391.0,
#     None,
#     None,
#     None],
#    ['2018-02-09',
#     None,
#     50.45,
#     48.62,
#     49.38,
#     None,
#     94709.0,
#     4675500.0,
#     None,
#     None,
#     None],
#    ['2018-02-08',
#     None,
#     51.55,
#     48.9,
#     49.06,
#     None,
#     135352.0,
#     6740505.0,
#     None,
#     None,
#     None],
#    ['2018-02-07',
#     None,
#     51.55,
#     49.28,
#     51.45,
#     None,
#     152153.0,
#     7735813.0,
#     None,
#     None,
#     None],
#    ['2018-02-06',
#     None,
#     50.1,
#     45.8,
#     49.54,
#     None,
#     283106.0,
#     13844855.0,
#     None,
#     None,
#     None],
#    ['2018-02-05',
#     None,
#     50.6,
#     48.92,
#     50.1,
#     None,
#     162996.0,
#     8145273.0,
#     None,
#     None,
#     None],
#    ['2018-02-02',
#     None,
#     51.95,
#     50.5,
#     50.6,
#     None,
#     102655.0,
#     5225053.0,
#     None,
#     None,
#     None],
#    ['2018-02-01',
#     None,
#     53.2,
#     51.85,
#     52.05,
#     None,
#     74150.0,
#     3879807.0,
#     None,
#     None,
#     None],
#    ['2018-01-31',
#     None,
#     53.2,
#     51.9,
#     52.75,
#     None,
#     86020.0,
#     4527940.0,
#     None,
#     None,
#     None],
#    ['2018-01-30',
#     None,
#     52.95,
#     52.0,
#     52.35,
#     None,
#     64262.0,
#     3366028.0,
#     None,
#     None,
#     None],
#    ['2018-01-29',
#     None,
#     54.25,
#     52.75,
#     53.0,
#     None,
#     73679.0,
#     3917787.0,
#     None,
#     None,
#     None],
#    ['2018-01-26',
#     None,
#     53.35,
#     52.05,
#     53.35,
#     None,
#     41175.0,
#     2182371.0,
#     None,
#     None,
#     None],
#    ['2018-01-25',
#     None,
#     53.1,
#     51.9,
#     52.35,
#     None,
#     60347.0,
#     3161715.0,
#     None,
#     None,
#     None],
#    ['2018-01-24',
#     None,
#     52.55,
#     51.95,
#     52.4,
#     None,
#     57224.0,
#     2995735.0,
#     None,
#     None,
#     None],
#    ['2018-01-23',
#     None,
#     52.95,
#     52.25,
#     52.5,
#     None,
#     65281.0,
#     3427258.0,
#     None,
#     None,
#     None],
#    ['2018-01-22',
#     None,
#     53.45,
#     51.8,
#     52.45,
#     None,
#     75149.0,
#     3928095.0,
#     None,
#     None,
#     None],
#    ['2018-01-19',
#     None,
#     53.55,
#     52.55,
#     53.25,
#     None,
#     58592.0,
#     3116070.0,
#     None,
#     None,
#     None],
#    ['2018-01-18',
#     None,
#     52.35,
#     51.65,
#     52.3,
#     None,
#     46582.0,
#     2429147.0,
#     None,
#     None,
#     None],
#    ['2018-01-17',
#     None,
#     51.75,
#     51.05,
#     51.7,
#     None,
#     57919.0,
#     2985441.0,
#     None,
#     None,
#     None],
#    ['2018-01-16',
#     None,
#     51.8,
#     51.2,
#     51.55,
#     None,
#     62912.0,
#     3239390.0,
#     None,
#     None,
#     None],
#    ['2018-01-15',
#     None,
#     52.35,
#     51.3,
#     51.75,
#     None,
#     83289.0,
#     4305279.0,
#     None,
#     None,
#     None],
#    ['2018-01-12',
#     None,
#     53.15,
#     51.05,
#     52.3,
#     None,
#     238861.0,
#     12470941.0,
#     None,
#     None,
#     None],
#    ['2018-01-11',
#     None,
#     55.25,
#     53.7,
#     54.4,
#     None,
#     173473.0,
#     9450601.0,
#     None,
#     None,
#     None],
#    ['2018-01-02',
#     52.05,
#     52.4,
#     51.2,
#     51.4,
#     None,
#     54435.0,
#     2807533.0,
#     None,
#     None,
#     None],
#    ['2017-12-29',
#     51.76,
#     51.94,
#     51.45,
#     51.76,
#     None,
#     34640.0,
#     1792304.0,
#     None,
#     None,
#     None],
#    ['2017-12-28',
#     51.65,
#     51.82,
#     51.43,
#     51.6,
#     None,
#     40660.0,
#     2099024.0,
#     None,
#     None,
#     None],
#    ['2017-12-27',
#     51.45,
#     51.89,
#     50.76,
#     51.82,
#     None,
#     57452.0,
#     2957018.0,
#     None,
#     None,
#     None],
#    ['2017-12-22',
#     51.05,
#     51.5,
#     50.92,
#     51.32,
#     None,
#     71165.0,
#     3641949.0,
#     None,
#     None,
#     None],
#    ['2017-12-21',
#     51.16,
#     51.52,
#     50.9,
#     51.4,
#     None,
#     120649.0,
#     6179433.0,
#     None,
#     None,
#     None],
#    ['2017-12-20',
#     51.88,
#     52.04,
#     51.2,
#     51.27,
#     None,
#     50587.0,
#     2610258.0,
#     None,
#     None,
#     None],
#    ['2017-12-19',
#     52.73,
#     52.73,
#     51.07,
#     51.66,
#     None,
#     137313.0,
#     7102361.0,
#     None,
#     None,
#     None],
#    ['2017-12-18',
#     52.37,
#     52.75,
#     51.61,
#     52.62,
#     None,
#     129733.0,
#     6770499.0,
#     None,
#     None,
#     None],
#    ['2017-12-15',
#     52.7,
#     52.7,
#     51.64,
#     52.01,
#     None,
#     204080.0,
#     10596319.0,
#     None,
#     None,
#     None],
#    ['2017-12-14',
#     53.11,
#     53.54,
#     52.15,
#     52.67,
#     None,
#     132981.0,
#     7016953.0,
#     None,
#     None,
#     None],
#    ['2017-12-13',
#     52.64,
#     53.35,
#     52.48,
#     53.09,
#     None,
#     128434.0,
#     6801159.0,
#     None,
#     None,
#     None],
#    ['2017-12-12',
#     52.29,
#     53.1,
#     51.82,
#     52.43,
#     None,
#     87911.0,
#     4615924.0,
#     None,
#     None,
#     None],
#    ['2017-12-11',
#     52.28,
#     52.45,
#     51.26,
#     52.14,
#     None,
#     71817.0,
#     3724193.0,
#     None,
#     None,
#     None],
#    ['2017-12-08',
#     51.5,
#     52.83,
#     51.28,
#     52.12,
#     None,
#     109157.0,
#     5690648.0,
#     None,
#     None,
#     None],
#    ['2017-12-07',
#     50.89,
#     51.47,
#     50.81,
#     51.47,
#     None,
#     48123.0,
#     2463848.0,
#     None,
#     None,
#     None],
#    ['2017-12-06',
#     50.8,
#     51.11,
#     50.39,
#     50.89,
#     None,
#     88730.0,
#     4504075.0,
#     None,
#     None,
#     None],
#    ['2017-12-05',
#     51.21,
#     51.38,
#     50.4,
#     51.25,
#     None,
#     83023.0,
#     4231971.0,
#     None,
#     None,
#     None],
#    ['2017-12-04',
#     49.5,
#     51.23,
#     49.5,
#     51.14,
#     None,
#     94385.0,
#     4800027.0,
#     None,
#     None,
#     None]],
#   'collapse': None,
#   'order': None,
#   'database_id': 6129}}

# %% [markdown]
# 1. Collect data from the Franfurt Stock Exchange, for the ticker AFX_X, for the whole year 2017 (keep in mind that the date format is YYYY-MM-DD).

# %%
url = 'https://www.quandl.com/api/v3/datasets/FSE/AFX_X.json?start_date=2017-01-01&end_date=2017-12-31&api_key=CeMyr24MyVqheK9FF32c'
r = requests.get(url, auth=('user', 'pass'))

# %%
afxdata = r.json()

# %% [markdown]
# 2. Convert the returned JSON object into a Python dictionary.

# %%
type(afxdata)
# Out:
# dict

# %% [markdown]
# 3. Calculate what the highest and lowest opening prices were for the stock in this period.

# %%
#get index of 'Open' which is 1
open_idx = afxdata['dataset']['column_names'].index('Open')

open_prices = []

for day in afxdata['dataset']['data']:
    if day[open_idx] != None:
        open_prices.append(day[open_idx])
        
print("The highest and lowest opening prices in 2017 were {} and {}{}".format(max(open_prices), min(open_prices), "."))
# Out:
# The highest and lowest opening prices in 2017 were 53.11 and 34.0.

# %% [markdown]
# 4. What was the largest change in any one day (based on High and Low price)?

# %%
high_idx = afxdata['dataset']['column_names'].index('High')
low_idx = afxdata['dataset']['column_names'].index('Low')

largest_change = 0

for day in afxdata['dataset']['data']:
    if abs(day[high_idx] - day[low_idx]) > largest_change:
        largest_change = abs(day[high_idx] - day[low_idx])
        
print("The largest change in any one day in 2017 was {:.2f}{}".format(largest_change, "."))
# Out:
# The largest change in any one day in 2017 was 2.81.

# %% [markdown]
# 5. What was the largest change between any two days (based on Closing Price)?

# %%
close_idx = afxdata['dataset']['column_names'].index('Close')

#initialize the day_before with the first day, since the first day has no previous day price
day_before = afxdata['dataset']['data'][0][close_idx]
largest_chage_closing = 0

for day in afxdata['dataset']['data']:
    if abs(day[close_idx] - day_before) > largest_chage_closing:
        largest_chage_closing = abs(day[close_idx] - day_before)
    day_before = day[close_idx]
    
print("The largest change between two days in 2017 was {:.2f}{}".format(largest_chage_closing, "."))
# Out:
# The largest change between two days in 2017 was 2.56.

# %% [markdown]
# 6. What was the average daily trading volume during this year?

# %%
trading_volume_idx = afxdata['dataset']['column_names'].index('Traded Volume')
trading_volume = []

for day in afxdata['dataset']['data']:
    trading_volume.append(day[trading_volume_idx])

if(len(trading_volume) != 0):
    avg_trading_volume = sum(trading_volume)/len(trading_volume)

print("The average daily trading volume during 2017 was {:.2f}{}".format(avg_trading_volume, "."))
# Out:
# The average daily trading volume during 2017 was 89124.34.

# %% [markdown]
# 7. (Optional) What was the median trading volume during this year. (Note: you may need to implement your own function for calculating the median.)

# %%
#l is a list to get the median

def get_median(l):   
    sorted_list = sorted(l)
    #list length is odd
    if(len(sorted_list)%2 != 0):
        med = sorted_list[len(sorted_list)//2]
    #list length is even
    else:
        med = (sorted_list[len(sorted_list)//2] + sorted_list[len(sorted_list)//2-1]) / 2       
    return med

print("The median trading volume during 2017 was {:.2f}{}".format(get_median(trading_volume), "."))
# Out:
# The median trading volume during 2017 was 76286.00.
